# %%
#this code 
import zipfile
from google.colab import drive
drive.mount('/content/drive/')

# %%
#zip_ref = zipfile.ZipFile("/content/drive/My Drive/hdfc/data.zip", 'r')
#zip_ref.extractall("/content/drive/My Drive/hdfc/")
#zip_ref.close()

# %%
import os
os.getcwd()
os.chdir('/content/drive/My Drive/hdfc/')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("DataSet/Train.csv")

# %%
df.head(10)
# Out:
#         Col1  Col2          Col3  ...  Col2395  Col2396  Col2397
# 0    RIGHGSN     1  1.086711e+04  ...     22.0     22.0      7.0
# 1  RIMHI5ZGP     0  2.584312e+05  ...     12.0     12.0     11.0
# 2  RIHOG1SZU     0  1.459355e+07  ...     21.0     21.0     16.0
# 3  RIHOLMQWU     0  6.727043e+05  ...    951.0    951.0    743.0
# 4  RIHO584ET     0 -1.218742e+06  ...   2205.0   2205.0   1831.0
# 5  RIHR51XD6     0  3.911176e+06  ...     20.0     20.0     18.0
# 6    RDHD6BX     0  1.173942e+05  ...      9.0      9.0      4.0
# 7    RS0UVS4     0  2.582386e+05  ...     18.0     15.0      5.0
# 8   TIWWI0K5     0  1.463930e+04  ...     12.0     12.0      6.0
# 9   T9VBLOY9     0  8.405841e+04  ...     10.0      9.0      4.0
#
# [10 rows x 2395 columns]

# %%
#preprocessing 
#1.check dataset contains any null
#2.check categorical data
#3.need decimal scalling

df.isnull().any(axis=0)

# %%
for i in range(3,len(df)):
    Check_Nan=(df['Col{}'.format(i)].isnull().any(axis=0))
    #if Nan value found then if condition true
    if  Check_Nan:
        print("****************before****************")
        print(df['Col{}'.format(i)])
        df['Col{}'.format(i)]=df['Col{}'.format(i)].fillna(np.mean(df['Col{}'.format(i)]))
        print("************after*********************")
        print(df['Col{}'.format(i)])
